# %% [markdown]
# # Your environnement

# %%
import os
print(os.getcwd())
# Out:
# C:\Travail\Enseignement\Cours_M2_python\2023\code

# %%
pip install flask_cors, flask_caching
# Out:
# Collecting flask_cors
#   Obtaining dependency information for flask_cors from https://files.pythonhosted.org/packages/10/69/1e6cfb87117568a9de088c32d6258219e9d1ff7c131abf74249ef2031279/Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata
#   Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: Flask>=0.9 in c:\tools\python\python310\lib\site-packages (from flask_cors) (2.2.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\tools\python\python310\lib\site-packages (from Flask>=0.9->flask_cors) (2.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\tools\python\python310\lib\site-packages (from Flask>=0.9->flask_cors) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\tools\python\python310\lib\site-packages (from Flask>=0.9->flask_cors) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\tools\python\python310\lib\site-packages (from Flask>=0.9->flask_cors) (8.1.3)
# Requirement already satisfied: colorama in c:\tools\python\python310\lib\site-packages (from click>=8.0->Flask>=0.9->flask_cors) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\tools\python\python310\lib\site-packages (from Jinja2>=3.0->Flask>=0.9->flask_cors) (2.1.2)
# Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Installing collected packages: flask_cors
# Successfully installed flask_cors-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#      -------------------- ----------------- 51.2/96.5 kB 871.5 kB/s eta 0:00:01
#      -------------------------------- ----- 81.9/96.5 kB 919.0 kB/s eta 0:00:01
#      -------------------------------------- 96.5/96.5 kB 784.5 kB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # First flask server
# using python 3.10

# %%
# -*- coding: utf-8 -*

from flask import Flask
app = Flask(__name__)


@app.route('/')
def hello_world():
    return 'Hello, World!'


if __name__ == '__main__':
    app.run(port=5050) # Permet de lancer le serveur directement depuis python en exécutant le programme
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5050
# Press CTRL+C to quit

# %% [markdown]
# # A more complicated one : Arctox server

# %% [markdown]
# First, read the data

# %%
import pandas as pd

df = pd.read_excel("C:\Travail\Enseignement\Cours_M2_python\Projet_Arctox\data for analyses_2010_2011_analyses.xls", 
                        sheet_name="data for analyses_2010_2011_ana")
    
## Check header
list(df)
df.columns
# Out:
# Index(['Year', 'Bird_ID', 'GLS_ID', 'Sex', 'Date', 'Nest', 'Nest_content',
#        'Capture_method', 'Headbill', 'Culmen', 'Wing', 'Right_tarsus', 'Mass',
#        'Index_body_condition', 'Muscle_Pectoral', 'Score_Personal', 'Long_Egg',
#        'Long_Egg_cm', 'Larg_Egg', 'Larg_Egg_cm', 'Vol_egg', 'Arrival_date',
#        'Arrival_date_num', 'Arrival_date_propre', 'Arrival_date_propre_num',
#        'date_enter_nest', 'date_enter_nest_num', 'Hatch_date',
#        'Hatch_date_num', 'weigh_hatching', 'Hatching_success',
#        'Chick_mass_gain_(g/d)_1st_15d', 'pente_chick_growth_1-15d',
#        'N_SIA_Blood', 'N_SIA_head_Feather', 'C_SIA_Blood',
#        'C_SIA_head_Feather', 'Chick_sex', 'Cortico', 'Hg_HF', 'Hg_blood',
#        'Season_Hg_Blood', 'Hg_BF', 'BF_side', 'Long_Median_15Oct_20Fev',
#        'Lat_Median_15Oct_20Fev', 'Long_Median_DecJan', 'Lat_Median_DecJan',
#        'Long_Median_Dec_20Fev', 'Lat_Median_Dec_20Fev', 'd_PL_15Oct_20Fev',
#        'd_PL_DecJan', 'd_PL_1Dec_20Fev', 'Max_d_col__Dec_Jan',
#        'Max_d_col__15Oct_20Fev', 'PL_Lat', 'PL_Long'],
#       dtype='object')

# %% [markdown]
# Now, output the data like json, with a print

# %%
import pandas as pd

df = pd.read_excel("C:\Travail\Enseignement\Cours_M2_python\Projet_Arctox\data for analyses_2010_2011_analyses.xls", 
                        sheet_name="data for analyses_2010_2011_ana")
    
## Check header
list(df)
df.columns

jsonx = df.to_json(orient='records')
type(jsonx)
#print(jsonx)

#import json 
json.dumps(jsonx)
# Out:
# '"[{\\"Year\\":2010.0,\\"Bird_ID\\":\\"LIAK10EG12\\",\\"GLS_ID\\":3506,\\"Sex\\":\\"F\\",\\"Date\\":1278806400000,\\"Nest\\":\\"M2\\",\\"Nest_content\\":\\"E\\",\\"Capture_method\\":\\"Nest\\",\\"Headbill\\":51.53,\\"Culmen\\":12.74,\\"Wing\\":118.0,\\"Right_tarsus\\":23.6,\\"Mass\\":150.0,\\"Index_body_condition\\":-5.175827,\\"Muscle_Pectoral\\":1.29,\\"Score_Personal\\":null,\\"Long_Egg\\":49.12,\\"Long_Egg_cm\\":4.912,\\"Larg_Egg\\":32.8,\\"Larg_Egg_cm\\":3.28,\\"Vol_egg\\":26.951083008,\\"Arrival_date\\":1275436800000,\\"Arrival_date_num\\":152.0,\\"Arrival_date_propre\\":1276041600000,\\"Arrival_date_propre_num\\":159.0,\\"date_enter_nest\\":null,\\"date_enter_nest_num\\":null,\\"Hatch_date\\":1279152000000,\\"Hatch_date_num\\":195.0,\\"weigh_hatching\\":null,\\"Hatching_success\\":\\"Y\\",\\"Chick_mass_gain_(g\\\\/d)_1st_15d\\":6.073,\\"pente_chick_growth_1-15d\\":6.939,\\"N_SIA_Blood\\":11.4284,\\"N_SIA_head_Feather\\":11.724,\\"C_SIA_Blood\\":-21.4147058824,\\"C_SIA_head_Feather\\":-19.361,\\"Chick_sex\\":null,\\"Cortico\\":16.9,\\"Hg_HF\\":3.13719,\\"Hg_blood\\":0.68939,\\"Season_Hg_Blood\\":\\"breeding\\",\\"Hg_BF\\":1.38873,\\"BF_side\\":\\"ventral\\",\\"Long_Median_15Oct_20Fev\\":34.9934442576,\\"Lat_Median_15Oct_20Fev\\":50.5345924888,\\"Long_Median_DecJan\\":37.6653306704,\\"Lat_Median_DecJan\\":47.992722735,\\"Long_Median_Dec_20Fev\\":35.8410588957,\\"Lat_Median_Dec_20Fev\\":48.3634864813,\\"d_PL_15Oct_20Fev\\":1068.6384023333,\\"d_PL_DecJan\\":816.3385860019,\\"d_PL_1Dec_20Fev\\":955.4316343156,\\"Max_d_col__Dec_Jan\\":4234.0313000728,\\"Max_d_col__15Oct_20Fev\\":4234.0313000728,\\"PL_Lat\\":46.6711508483,\\"PL_Long\\":48.3299639281},{\\"Year\\":2010.0,\\"Bird_ID\\":\\"LIAK10EG35\\",\\"GLS_ID\\":3597,\\"Sex\\":\\"F\\",\\"Date\\":1279065600000,\\"Nest\\":null,\\"Nest_content\\":null,\\"Capture_method\\":\\"Lasso\\",\\"Headbill\\":53.71,\\"Culmen\\":14.39,\\"Wing\\":119.0,\\"Right_tarsus\\":22.19,\\"Mass\\":155.0,\\"Index_body_condition\\":-1.695129,\\"Muscle_Pectoral\\":0.99,\\"Score_Personal\\":2.0,\\"Long_Egg\\":null,\\"Long_Egg_cm\\":null,\\"Larg_Egg\\":null,\\"Larg_Egg_cm\\":null,\\"Vol_egg\\":null,\\"Arrival_date\\":1277424000000,\\"Arrival_date_num\\":175.0,\\"Arrival_date_propre\\":1277424000000,\\"Arrival_date_propre_num\\":175.0,\\"date_enter_nest\\":1277510400000,\\"date_enter_nest_num\\":176.0,\\"Hatch_date\\":null,\\"Hatch_date_num\\":null,\\"weigh_hatching\\":null,\\"Hatching_success\\":\\"Unk\\",\\"Chick_mass_gain_(g\\\\/d)_1st_15d\\":null,\\"pente_chick_growth_1-15d\\":null,\\"N_SIA_Blood\\":11.567,\\"N_SIA_head_Feather\\":12.456,\\"C_SIA_Blood\\":-20.9258,\\"C_SIA_head_Feather\\":-16.4686666667,\\"Chick_sex\\":null,\\"Cortico\\":9.7,\\"Hg_HF\\":3.24384,\\"Hg_blood\\":0.95481,\\"Season_Hg_Blood\\":\\"breeding\\",\\"Hg_BF\\":1.65412,\\"BF_side\\":\\"dorsal\\",\\"Long_Median_15Oct_20Fev\\":50.6510313553,\\"Lat_Median_15Oct_20Fev\\":40.7309475411,\\"Long_Median_DecJan\\":51.5777900298,\\"Lat_Median_DecJan\\":40.3428448477,\\"Long_Median_Dec_20Fev\\":51.0245815409,\\"Lat_Median_Dec_20Fev\\":39.9659895055,\\"d_PL_15Oct_20Fev\\":686.2822971545,\\"d_PL_DecJan\\":750.6668794938,\\"d_PL_1Dec_20Fev\\":776.6645008781,\\"Max_d_col__Dec_Jan\\":5467.6876604456,\\"Max_d_col__15Oct_20Fev\\":5835.9432596217,\\"PL_Lat\\":null,\\"PL_Long\\":null},{\\"Year\\":2010.0,\\"Bird_ID\\":\\"LIAK10EG32\\",\\"GLS_ID\\":3600,\\"Sex\\":\\"F\\",\\"Date\\":1278979200000,\\"Nest\\":\\"M7\\",\\"Nest_content\\":\\"E\\",\\"Capture_method\\":\\"Nest\\",\\"Headbill\\":50.3,\\"Culmen\\":13.83,\\"Wing\\":121.0,\\"Right_tarsus\\":20.12,\\"Mass\\":140.0,\\"Index_body_condition\\":-6.038971,\\"Muscle_Pectoral\\":0.9,\\"Score_Personal\\":1.0,\\"Long_Egg\\":44.2,\\"Long_Egg_cm\\":4.42,\\"Larg_Egg\\":30.34,\\"Larg_Egg_cm\\":3.034,\\"Vol_egg\\":20.7502626552,\\"Arrival_date\\":null,\\"Arrival_date_num\\":null,\\"Arrival_date_propre\\":null,\\"Arrival_date_propre_num\\":null,\\"date_enter_nest\\":null,\\"date_enter_nest_num\\":null,\\"Hatch_date ...

# %% [markdown]
# Run a flask server on port 80 and give a new route for the app

# %%
#!/usr/bin/python3
# -*-coding:UTF-8 -*

'''
Created on 12 october 2020
@author: cplumejeaud, 

Used to push arctox data on the Web
'''

from flask import Flask, jsonify, abort, render_template,url_for,request, make_response
from flask_cors import CORS, cross_origin
from flask_caching import Cache

import csv
import json
import io
import os

import pandas as pd

#APP_ROOT = os.path.dirname(os.path.abspath(__file__))   # refers to application_top
#APP_STATIC = os.path.join(APP_ROOT, 'static')
#APP_DATA = os.path.join(APP_STATIC, 'data')

app = Flask(__name__)
#CORS(app)

    
port = '80'

@app.route('/alldata/')
def hello_world():
    return 'Hello, World! the route is new'



if __name__ == '__main__':
    app.run(debug=False,port=port,threaded=True)  
    #Note that debug=True is a problem inside a jupyter notebook
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:80
# Press CTRL+C to quit
# 127.0.0.1 - - [16/Oct/2023 16:18:04] "GET /alldata HTTP/1.1" 308 -
# 127.0.0.1 - - [16/Oct/2023 16:18:04] "GET /alldata/ HTTP/1.1" 200 -

# %% [markdown]
# Now, combine the flask server with the data you've read
# 1. create a method  *read_data* that prints or return a dummy sentence (see the difference)
# 2. put the reading of Excel data into this *read_data* method

# %%
#!/usr/bin/python3
# -*-coding:UTF-8 -*

'''
Created on 12 october 2020
@author: cplumejeaud, 

Used to push arctox data on the Web
'''

from flask import Flask, jsonify, abort, render_template,url_for,request, make_response
from flask_cors import CORS, cross_origin
from flask_caching import Cache

import csv
import json
import io
import os

import pandas as pd

#APP_ROOT = os.path.dirname(os.path.abspath(__file__))   # refers to application_top
#APP_STATIC = os.path.join(APP_ROOT, 'static')
#APP_DATA = os.path.join(APP_STATIC, 'data')

app = Flask(__name__)

    
port = '80'

@app.route('/alldata/')
def hello_world():
    return read_data()

def read_data():
    #print('the route is new') #This is a bug
    return 'The route is really new !'

if __name__ == '__main__':
    app.run(debug=False,port=port,threaded=True)  
    #Note that debug=True is a problem inside a jupyter notebook
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:80
# Press CTRL+C to quit
# 127.0.0.1 - - [16/Oct/2023 16:23:36] "GET /alldata/ HTTP/1.1" 200 -

# %% [markdown]
# Do the whole job

# %%
#!/usr/bin/python3
# -*-coding:UTF-8 -*

'''
Created on 12 october 2020
@author: cplumejeaud, 

Used to push arctox data on the Web
'''

from flask import Flask, jsonify, abort, render_template,url_for,request, make_response
from flask_cors import CORS, cross_origin
from flask_caching import Cache

import csv
import json
import io
import os

import pandas as pd

#APP_ROOT = os.path.dirname(os.path.abspath(__file__))   # refers to application_top
#APP_STATIC = os.path.join(APP_ROOT, 'static')
#APP_DATA = os.path.join(APP_STATIC, 'data')

app = Flask(__name__)

    
port = '80'

@app.route('/alldata/')
def hello_world():
    return read_data()

def read_data():
    #print('the route is new') #This is a bug
    #return 'The route is really new !'

    df = pd.read_excel("C:\Travail\Enseignement\Cours_M2_python\Projet_Arctox\data for analyses_2010_2011_analyses.xls", 
                            sheet_name="data for analyses_2010_2011_ana")


    jsonx = df.to_json(orient='records')
    #print(jsonx)

    return json.dumps(jsonx)

if __name__ == '__main__':
    app.run(debug=False,port=port,threaded=True)  
    #Note that debug=True is a problem inside a jupyter notebook
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:80
# Press CTRL+C to quit
# 127.0.0.1 - - [16/Oct/2023 16:30:38] "GET /alldata/ HTTP/1.1" 200 -
